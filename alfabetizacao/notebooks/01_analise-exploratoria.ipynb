# %% [markdown]
# # Importação

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# # 9542 (Números absolutos)

# %%
df = pd.read_csv("../dados/brutos/9542_2022_brasil_regioes_uf.csv", sep=";", encoding="utf-8", decimal=",", skiprows=5)

print("-----Tabela 9542-----")
df.shape
# Out:
# -----Tabela 9542-----
# (1600, 13)

# %%
df.columns.tolist()
# Out:
# ['Cód.',
#  'Brasil, Grande Região e Unidade da Federação',
#  'Cor ou raça',
#  'Idade',
#  'Total',
#  'Homens',
#  'Mulheres',
#  'Total.1',
#  'Homens.1',
#  'Mulheres.1',
#  'Total.2',
#  'Homens.2',
#  'Mulheres.2']

# %%
df.head(10)
# Out:
#   Cód. Brasil, Grande Região e Unidade da Federação Cor ou raça  \
# 0    1                                       Brasil       Total
# 1    1                                       Brasil       Total
# 2    1                                       Brasil       Total
# 3    1                                       Brasil       Total
# 4    1                                       Brasil       Total
# 5    1                                       Brasil       Total
# 6    1                                       Brasil       Total
# 7    1                                       Brasil       Total
# 8    1                                       Brasil      Branca
# 9    1                                       Brasil      Branca
#
#              Idade        Total      Homens    Mulheres      Total.1  \
# 0            Total  162951495.0  78066714.0  84884781.0  151547694.0
# 1     15 a 19 anos   14375942.0   7317515.0   7058427.0   14154728.0
# ...

# %% [markdown]
# # 9543 (Taxa de Alfabetização)

# %%
df_taxa = pd.read_csv("../dados/brutos/9543_2022_brasil_regioes_uf.csv", sep=";", encoding="utf-8", decimal=",", skiprows=5)

print("-----Tabela 9543 (Taxa)-----")
df_taxa.shape
# Out:
# -----Tabela 9543 (Taxa)-----
# (280, 21)

# %%
df_taxa.head(10)
# Out:
#   Cód. Brasil, Grande Região e Unidade da Federação            Idade  Total  \
# 0    1                                       Brasil            Total  93.00
# 1    1                                       Brasil     15 a 19 anos  98.46
# 2    1                                       Brasil     20 a 24 anos  98.46
# 3    1                                       Brasil     25 a 34 anos  98.04
# 4    1                                       Brasil     35 a 44 anos  95.89
# 5    1                                       Brasil     45 a 54 anos  92.17
# 6    1                                       Brasil     55 a 64 anos  88.53
# 7    1                                       Brasil  65 anos ou mais  79.75
# 8    1                                        Norte            Total  91.84
# 9    1                                        Norte     15 a 19 anos  97.77
#
#    Branca  Preta  Amarela  Parda  Indígena  Total.1  ...  Preta.1  Amarela.1  \
# ...

# %%
df_taxa.columns.tolist()
# Out:
# ['Cód.',
#  'Brasil, Grande Região e Unidade da Federação',
#  'Idade',
#  'Total',
#  'Branca',
#  'Preta',
#  'Amarela',
#  'Parda',
#  'Indígena',
#  'Total.1',
#  'Branca.1',
#  'Preta.1',
#  'Amarela.1',
#  'Parda.1',
#  'Indígena.1',
#  'Total.2',
#  'Branca.2',
#  'Preta.2',
#  'Amarela.2',
#  'Parda.2',
#  'Indígena.2']
